# %%
import sys
#sys.path.append("/home/ubuntu/projects/ts-graph-inference/")

#from ts_graph_inference.data_utils import *
import seaborn as sns
import matplotlib.pyplot as plt


import msprime
#import allel
from scipy.spatial.distance import squareform
from sklearn.metrics import pairwise_distances
import numpy as np
import pandas as pd

# %%
def get_population_time(time_rate:float=0.06, tmax:int = 130_000,
                        num_time_windows:int = 21
                       ) -> np.array :
    """Creates population time points; used as time points to change
    population size changes for simulation
    
    :return numpy.ndarray: time points of length num_time_windows
    """

    population_time = np.repeat([(np.exp(np.log(1 + time_rate * tmax) * i /
                              (num_time_windows - 1)) - 1) / time_rate for i in
                              range(num_time_windows)], 1, axis=0)
    population_time[0] = 1
    return population_time


def sample_population_size(n_min:int=10, n_max:int=100_000, num_time_windows=21) -> list[float]:

    """Creates random demography. Function taken from: 
    https://gitlab.inria.fr/ml_genetics/public/dlpopsize_paper
    
    :param int n_min: Lower-bound of demography.
    :param int n_max: Upper-bound of demography.
    :param int num_time_windows: Number of population sizes in demography.
    :return list: 
    """

    n_min_log10 = np.log10(n_min)
    n_max_log10 = np.log10(n_max)
    population_size = [10 ** np.random.uniform(low=n_min_log10, high=n_max_log10)]
    for j in range(num_time_windows - 1):
        population_size.append(10 ** n_min_log10 - 1)
        while population_size[-1] > 10 ** n_max_log10 or population_size[-1]  < 10 ** n_min_log10:
            population_size[-1] = population_size[-2] * 10 ** np.random.uniform(-1, 1)

    return population_size


def get_random_time_and_demography():
    from scipy.interpolate import interp1d
    upper_out_of_bound = lower_out_of_bound = True
    while upper_out_of_bound or lower_out_of_bound:
        steps = 18
        x = np.log(get_population_time(time_rate=0.1, num_time_windows=steps, tmax=10_000_000).tolist())
        y = np.log(sample_population_size(10_000, 10_000_000, steps))
        xnew = np.linspace(x[0], x[-1], num=10000, endpoint=True)
        f_cubic = interp1d(x, y, kind='cubic')
        ynew = f_cubic(xnew)
        upper_out_of_bound = np.sum(np.exp(ynew) > 10_000_000) > 0
        lower_out_of_bound = np.sum(np.exp(ynew) < 10_000) > 0
    x_sample = xnew[np.linspace(10, 9999, 60).astype(int)]
    y_sample = ynew[np.linspace(10, 9999, 60).astype(int)]
    demography = np.exp(y_sample)
    population_time = np.exp(x_sample)
    return population_time, demography

population_time, demography = get_random_time_and_demography()
#sns.lineplot(x=population_time, y=demography)
#plt.yscale('log')
#plt.xscale('log')
#plt.ylim(1000, 100_000_000)
#plt.xlim(10,10_000_000)

# %%
def treeseq2df(ts, addedhue=None, w=100):
    gn = allel.HaplotypeArray(ts.genotype_matrix())
    r = allel.rogers_huff_r(gn)
    s = squareform(r ** 2)
    s = np.triu(s)
    n_genotypes = s.shape[0]
    
    m = pd.DataFrame(s).melt()
    m.columns = ["genotype1", "distance"]
    m["genotype2"] = np.tile(np.arange(n_genotypes), n_genotypes)
    
    positions = [s.position for s in ts.sites()]
    m["position"] = np.tile(positions, n_genotypes)
    
    distance = pairwise_distances(np.array(positions)[None].T)
    pairdistances = pd.DataFrame(distance).melt().value.tolist()
    m["pairdistances"] = pairdistances
    
    if addedhue: m["hue"] = addedhue
    sm = m[m["distance"] >= 0.1]
    
    
    sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
    df2 = sm[["distance", "binned","hue"]].groupby(sm['binned']).mean().reset_index()
    position = [bin.left for bin in df2.binned]
    df2["position"] = position
    
    
    return df2

# %%
import msprime

def kingman_constant(Ne=10**4, L=10_000_000, r=5e-8, num_replicates=1000):
    sample_size = 10
    alpha = 2.0
    demography=msprime.Demography()
    demography.add_population(initial_size=(Ne))
    db = msprime.DemographyDebugger(demography=demography)
    tree_sequences = msprime.sim_ancestry(samples=sample_size,
                            recombination_rate=r,
                            sequence_length=L,
                            demography=demography,ploidy=1,random_seed=((alpha+1)**2), num_replicates=num_replicates)
    demography = db.population_size_trajectory(population_time).flatten()
    return list(tree_sequences), demography 

def beta_constant(alpha, Ne = 10**6, r=5e-8,  L=10**4, num_replicates=1000):
    
    sample_size=10
    mu=1e-8
    
    demography=msprime.Demography()
    demography.add_population(initial_size=(Ne))

    db = msprime.DemographyDebugger(demography=demography,model=msprime.BetaCoalescent(alpha=alpha))
    tree_sequences = msprime.sim_ancestry(samples=10,
                                          recombination_rate=r, sequence_length=L, demography=demography,
                                          ploidy=1,model=msprime.BetaCoalescent(alpha=alpha),
                                          num_replicates=num_replicates)
    demography = db.population_size_trajectory(population_time).flatten()
    
    return list(tree_sequences), demography

# %%
#kingman_trees, _ = kingman_constant(Ne=10**4, L=10**4,  r=5e-8)

#beta_trees_1, _ = beta_constant(alpha=1.5, Ne=10**6, L=10**6,  r=5e-8)

#beta_trees_2, _ = beta_constant(alpha=1.1, Ne=10**6, L=100_000_000,  r=5e-8)

# %%
dfs = []
w = 50
for i, ts in enumerate(tqdm(kingman_trees[:1000])):
    ts = msprime.mutate(ts, rate=1e-7)
    df = treeseq2df(ts, str(i), w)
    dfs.append(df)
kingman_dfs = pd.concat(dfs)
kingman_dfs.reset_index(inplace=True)
kingman_dfs["binned"] = None
#dfs.to_csv("k_r5e-8_m1e-7_w200_l1e4.csv")
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [00:28<00:00, 35.23it/s]

# %%
dfs = []
w = 100
for i, ts in enumerate(tqdm(beta_trees_1[:1000])):
    ts = msprime.mutate(ts, rate=1e-7)
    df = treeseq2df(ts, str(i), w)
    dfs.append(df)
    
beta_dfs = pd.concat(dfs)
beta_dfs.reset_index(inplace=True)
beta_dfs["binned"] = None
#beta_dfs.to_csv("mmc_a15_r5e-8_m1e-7_w1e5_l1e5.csv")
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [05:31<00:00,  3.02it/s]

# %%
dfs = []
w = 100
for i, ts in enumerate(tqdm(beta_trees_2[:1000])):
    ts = msprime.mutate(ts, rate=1e-7)
    df = treeseq2df(ts, str(i), w)
    dfs.append(df)
    
beta_dfs_2 = pd.concat(dfs)
beta_dfs_2.reset_index(inplace=True)
beta_dfs_2["binned"] = None
#beta_dfs.to_csv("mmc_a11_r5e-8_m1e-7_w1e6_l1e8.csv")
# Out:
# 100%|█████████████████████████████████████| 1000/1000 [1:07:49<00:00,  4.07s/it]

# %%
kingman_dfs = pd.read_csv("kingman_ld.csv")
beta_dfs = pd.read_csv("mmc_1.5_ld.csv")
beta_dfs_2 = pd.read_csv("mmc_1.1_ld.csv")

# %%
sns.set(font_scale=1.5)
sns.set_style("ticks")

fig, ax = plt.subplots(1, 3, figsize=(16,4), sharex=False, sharey=True)

dfs = kingman_dfs
sns.lineplot(data=dfs, x="position", y="distance", ax=ax[0])
ax[0].set_xlabel("sequence [bp]")
ax[0].set_ylabel("linkage disequilibirum [r²]")
ax[0].set_title("A) kingman-coal. (window 200)", loc="left")
ax[0].grid(True)

#dfs.to_csv("a15_r2e-8_m2e-7_w50_l1e6.csv")
dfs = beta_dfs
sns.lineplot(data=dfs, x="position", y="distance", ax=ax[1])
ax[1].set_xlabel("sequence [bp]")
ax[1].set_ylabel("linkage disequilibirum [r²]")
ax[1].set_title("B) β-coal. α=1.5 (window 10⁵)", loc="left")
ax[1].grid(True)

dfs = beta_dfs_2
sns.lineplot(data=dfs, x="position", y="distance", ax=ax[2])
ax[2].set_xlabel("sequence [bp]")
ax[2].set_ylabel("linkage disequilibirum [r²]")
ax[2].set_title("C) β-coal. α=1.1 (window 10⁶)", loc="left")
ax[2].grid(True)

plt.tight_layout()

fig.savefig("../figures/Figure_2.pdf", dpi=600)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,6), sharex=False, sharey=False)
dfs = kingman_dfs
sns.lineplot(data=dfs, x="position", y="distance", ax=ax)
ax.set_xlabel("sequence [bp]")
ax.set_ylabel("linkage disequilibirum [r²]")
ax.set_title("A) kingman (window 200)")
ax.grid(True)
ax.set(ylim=(0.30, 0.6))
fig.savefig("../figures/figure_2_A", dpi=500)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,6), sharex=False, sharey=False)
dfs = beta_dfs
sns.lineplot(data=dfs, x="position", y="distance", ax=ax)
ax.set_xlabel("sequence [bp]")
ax.set_ylabel("linkage disequilibirum [r²]")
ax.set_title("B) beta coal. α=1.5 (window 10⁵)")
ax.grid(True)
ax.set(ylim=(0.30, 0.6))
fig.savefig("../figures/figure_2_B", dpi=500)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,6), sharex=False, sharey=False)
dfs = beta_dfs_2
sns.lineplot(data=dfs, x="position", y="distance", ax=ax)
ax.set_xlabel("sequence [bp]")
ax.set_ylabel("linkage disequilibirum [r²]")
ax.set_title("C) beta coal. α=1.1 (window 10⁶)")
ax.set(ylim=(0.3, 0.6))
ax.grid(True)
fig.savefig("../figures/figure_2_C", dpi=500)

# %%
kingman_dfs.to_csv("kingman_ld.csv")
beta_dfs.to_csv("mmc_1.5_ld.csv")
beta_dfs_2.to_csv("mmc_1.1_ld.csv")

# %%
from tqdm import tqdm
import allel

# %%
beta_trees_15, _ = beta_constant(alpha=1.5, Ne=10**6, L=10**6,  r=5e-8)

# %%
dfs = []
w = 100
for i, ts in enumerate(tqdm(beta_trees_15[:100])):
    ts = msprime.mutate(ts, rate=1e-7)
    df = treeseq2df(ts, str(i), w)
    dfs.append(df)
    
beta_dfs = pd.concat(dfs)
beta_dfs.reset_index(inplace=True)
beta_dfs["binned"] = None
#beta_dfs.to_csv("mmc_a15_r5e-8_m1e-7_w1e5_l1e5.csv")
# Out:
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#   1%|▍                                          | 1/100 [00:00<01:35,  1.04it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#   2%|▊                                          | 2/100 [00:01<00:49,  1.99it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#   3%|█▎                                         | 3/100 [00:01<00:50,  1.91it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#   4%|█▋                                         | 4/100 [00:02<00:43,  2.22it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#   5%|██▏                                        | 5/100 [00:02<00:33,  2.80it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#   6%|██▌                                        | 6/100 [00:02<00:30,  3.04it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#   7%|███                                        | 7/100 [00:02<00:30,  3.07it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#   8%|███▍                                       | 8/100 [00:03<00:30,  3.06it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#   9%|███▊                                       | 9/100 [00:03<00:33,  2.75it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  10%|████▏                                     | 10/100 [00:04<00:41,  2.17it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  11%|████▌                                     | 11/100 [00:04<00:46,  1.93it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  12%|█████                                     | 12/100 [00:05<00:36,  2.39it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  13%|█████▍                                    | 13/100 [00:05<00:40,  2.15it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  14%|█████▉                                    | 14/100 [00:05<00:31,  2.69it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  15%|██████▎                                   | 15/100 [00:06<00:27,  3.10it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  16%|██████▋                                   | 16/100 [00:06<00:22,  3.76it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  17%|███████▏                                  | 17/100 [00:06<00:22,  3.72it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  18%|███████▌                                  | 18/100 [00:06<00:27,  3.03it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  19%|███████▉                                  | 19/100 [00:07<00:24,  3.29it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  20%|████████▍                                 | 20/100 [00:07<00:26,  3.06it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  21%|████████▊                                 | 21/100 [00:07<00:25,  3.13it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  22%|█████████▏                                | 22/100 [00:08<00:26,  2.97it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  23%|█████████▋                                | 23/100 [00:08<00:24,  3.10it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  24%|██████████                                | 24/100 [00:08<00:22,  3.33it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  25%|██████████▌                               | 25/100 [00:08<00:18,  4.11it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  26%|██████████▉                               | 26/100 [00:09<00:20,  3.61it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  27%|███████████▎                              | 27/100 [00:09<00:23,  3.17it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  28%|███████████▊                              | 28/100 [00:10<00:25,  2.77it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  29%|████████████▏                             | 29/100 [00:10<00:24,  2.86it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  30%|████████████▌                             | 30/100 [00:10<00:22,  3.12it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  31%|█████████████                             | 31/100 [00:11<00:22,  3.04it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
# /tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  33%|█████████████▊                            | 33/100 [00:11<00:15,  4.45it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  34%|██████████████▎                           | 34/100 [00:11<00:19,  3.39it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  35%|██████████████▋                           | 35/100 [00:11<00:15,  4.09it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  36%|███████████████                           | 36/100 [00:12<00:16,  3.94it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  37%|███████████████▌                          | 37/100 [00:12<00:16,  3.80it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  38%|███████████████▉                          | 38/100 [00:12<00:19,  3.21it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  39%|████████████████▍                         | 39/100 [00:13<00:22,  2.69it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
# /tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  41%|█████████████████▏                        | 41/100 [00:13<00:19,  3.08it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  42%|█████████████████▋                        | 42/100 [00:14<00:21,  2.72it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  43%|██████████████████                        | 43/100 [00:14<00:21,  2.63it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  44%|██████████████████▍                       | 44/100 [00:15<00:19,  2.89it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  45%|██████████████████▉                       | 45/100 [00:15<00:17,  3.14it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  46%|███████████████████▎                      | 46/100 [00:15<00:18,  2.94it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  47%|███████████████████▋                      | 47/100 [00:16<00:17,  2.96it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  48%|████████████████████▏                     | 48/100 [00:16<00:17,  3.00it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  49%|████████████████████▌                     | 49/100 [00:16<00:16,  3.02it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  50%|█████████████████████                     | 50/100 [00:17<00:16,  2.96it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  51%|█████████████████████▍                    | 51/100 [00:17<00:17,  2.73it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  52%|█████████████████████▊                    | 52/100 [00:17<00:17,  2.76it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  53%|██████████████████████▎                   | 53/100 [00:18<00:16,  2.83it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  54%|██████████████████████▋                   | 54/100 [00:18<00:16,  2.71it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  55%|███████████████████████                   | 55/100 [00:18<00:15,  2.83it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  56%|███████████████████████▌                  | 56/100 [00:19<00:14,  3.01it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  57%|███████████████████████▉                  | 57/100 [00:19<00:12,  3.47it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  58%|████████████████████████▎                 | 58/100 [00:19<00:13,  3.04it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  59%|████████████████████████▊                 | 59/100 [00:20<00:15,  2.66it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  60%|█████████████████████████▏                | 60/100 [00:20<00:13,  3.03it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  61%|█████████████████████████▌                | 61/100 [00:21<00:16,  2.42it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  62%|██████████████████████████                | 62/100 [00:21<00:20,  1.86it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  63%|██████████████████████████▍               | 63/100 [00:22<00:17,  2.17it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  64%|██████████████████████████▉               | 64/100 [00:22<00:16,  2.20it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  65%|███████████████████████████▎              | 65/100 [00:22<00:13,  2.53it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  66%|███████████████████████████▋              | 66/100 [00:23<00:12,  2.62it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  67%|████████████████████████████▏             | 67/100 [00:23<00:09,  3.36it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  68%|████████████████████████████▌             | 68/100 [00:23<00:08,  3.89it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  69%|████████████████████████████▉             | 69/100 [00:23<00:07,  4.27it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  70%|█████████████████████████████▍            | 70/100 [00:24<00:08,  3.53it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  71%|█████████████████████████████▊            | 71/100 [00:24<00:08,  3.26it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  72%|██████████████████████████████▏           | 72/100 [00:24<00:09,  2.82it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  73%|██████████████████████████████▋           | 73/100 [00:25<00:12,  2.19it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  74%|███████████████████████████████           | 74/100 [00:25<00:09,  2.84it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  75%|███████████████████████████████▌          | 75/100 [00:26<00:10,  2.32it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  76%|███████████████████████████████▉          | 76/100 [00:26<00:10,  2.28it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  77%|████████████████████████████████▎         | 77/100 [00:27<00:09,  2.55it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  78%|████████████████████████████████▊         | 78/100 [00:27<00:07,  2.92it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  79%|█████████████████████████████████▏        | 79/100 [00:27<00:08,  2.59it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  80%|█████████████████████████████████▌        | 80/100 [00:28<00:07,  2.56it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  81%|██████████████████████████████████        | 81/100 [00:28<00:08,  2.37it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  82%|██████████████████████████████████▍       | 82/100 [00:29<00:08,  2.18it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  83%|██████████████████████████████████▊       | 83/100 [00:30<00:09,  1.76it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  84%|███████████████████████████████████▎      | 84/100 [00:30<00:07,  2.06it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  85%|███████████████████████████████████▋      | 85/100 [00:30<00:07,  2.11it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  86%|████████████████████████████████████      | 86/100 [00:31<00:06,  2.10it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  87%|████████████████████████████████████▌     | 87/100 [00:31<00:05,  2.37it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  88%|████████████████████████████████████▉     | 88/100 [00:32<00:05,  2.14it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
# /tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  90%|█████████████████████████████████████▊    | 90/100 [00:32<00:03,  3.10it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  91%|██████████████████████████████████████▏   | 91/100 [00:33<00:03,  2.46it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  92%|██████████████████████████████████████▋   | 92/100 [00:33<00:03,  2.60it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  93%|███████████████████████████████████████   | 93/100 [00:33<00:02,  2.98it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  94%|███████████████████████████████████████▍  | 94/100 [00:33<00:01,  3.24it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  95%|███████████████████████████████████████▉  | 95/100 [00:34<00:01,  3.83it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  96%|████████████████████████████████████████▎ | 96/100 [00:34<00:01,  3.42it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  97%|████████████████████████████████████████▋ | 97/100 [00:34<00:00,  3.05it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  98%|█████████████████████████████████████████▏| 98/100 [00:35<00:00,  3.11it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
#  99%|█████████████████████████████████████████▌| 99/100 [00:35<00:00,  2.94it/s]/tmp/ipykernel_11333/2209556902.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
# 100%|█████████████████████████████████████████| 100/100 [00:35<00:00,  2.79it/s]

# %%
    w = 10
    gn = allel.HaplotypeArray(ts.genotype_matrix())
    r = allel.rogers_huff_r(gn)
    s = squareform(r ** 2)
    s = np.triu(s)
    n_genotypes = s.shape[0]
    
    m = pd.DataFrame(s).melt()
    m.columns = ["genotype1", "distance"]
    m["genotype2"] = np.tile(np.arange(n_genotypes), n_genotypes)
    
    positions = [s.position for s in ts.sites()]
    m["position"] = np.tile(positions, n_genotypes)
    
    distance = pairwise_distances(np.array(positions)[None].T)
    pairdistances = pd.DataFrame(distance).melt().value.tolist()
    m["pairdistances"] = pairdistances
    
    sm = m[m["distance"] >= 0.1]

# %%
sm
# Out:
#          genotype1  distance  genotype2       position  pairdistances
# 1657             1  0.259259          0     426.308176    1617.995023
# 3314             2  0.259259          0     426.308176    2424.775502
# 4971             3  0.583333          0     426.308176    2519.322121
# 4972             3  0.444445          1    2044.303200     901.327097
# 4973             3  0.444445          2    2851.083678      94.546619
# ...            ...       ...        ...            ...            ...
# 2745639       1656  0.583333       1647  984130.869075   14417.157580
# 2745640       1656  1.000000       1648  985938.891547   12609.135108
# 2745642       1656  0.583333       1650  987183.824288   11364.202367
# 2745645       1656  0.444444       1653  991926.779511    6621.247145
# 2745646       1656  0.583333       1654  994097.420089    4450.606567
#
# [744503 rows x 5 columns]

# %%
gn = allel.HaplotypeArray(ts.genotype_matrix())
r = allel.rogers_huff_r(gn)
s = squareform(r ** 2)
s = np.triu(s)
n_genotypes = s.shape[0]

m = pd.DataFrame(s).melt()
m.columns = ["genotype1", "distance"]
m["genotype2"] = np.tile(np.arange(n_genotypes), n_genotypes)

positions = [s.position for s in ts.sites()]
m["position"] = np.tile(positions, n_genotypes)

distance = pairwise_distances(np.array(positions)[None].T)
pairdistances = pd.DataFrame(distance).melt().value.tolist()
m["pairdistances"] = pairdistances

sm = m[m["distance"] >= 0.1]


sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))
df2 = sm[["distance", "binned"]].groupby(sm['binned']).mean().reset_index()
position = [bin.left for bin in df2.binned]
df2["position"] = position
# Out:
# /tmp/ipykernel_11333/3311482978.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['binned'] = pd.cut(x=sm['pairdistances'], bins=np.linspace(0, ts.sequence_length, w))

# %%
df2
df2.reset_index(inplace=True)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,6), sharex=False, sharey=False)

sns.lineplot(data=df2, x="position", y="distance", ax=ax)
ax.set_xlabel("sequence [bp]")
ax.set_ylabel("linkage disequilibirum [r²]")
# Out:
# Text(0, 0.5, 'linkage disequilibirum [r²]')

# %%
beta_dfs
# Out:
#       index binned  distance    position
# 0         0   None  0.496202       0.000
# 1         1   None  0.401494   10101.010
# 2         2   None  0.361812   20202.020
# 3         3   None  0.342494   30303.030
# 4         4   None  0.315720   40404.040
# ...     ...    ...       ...         ...
# 9895     94   None  0.236100  949494.949
# 9896     95   None  0.185496  959595.960
# 9897     96   None  0.185626  969696.970
# 9898     97   None  0.175505  979797.980
# 9899     98   None  0.147619  989898.990
#
# [9900 rows x 4 columns]
