# %%
import msprime
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import torch
# %matplotlib inline

# %%
label_lookup = {
    "kingman_selection_none" : 0,
    "kingman_selection_weak" : 1,
    "kingman_selection_medium" : 2,
    "kingman_selection_strong" : 3,
    
    "beta_selection_none" : 4,
    "beta_selection_weak" : 5,
    "beta_selection_medium" : 6,
    "beta_selection_strong" : 7,    
}

# %%
def simulate_tree_sequence(L, model, seed, sample_size = 10, r = 1e-8, Ne = 100_000):
    
    demography=msprime.Demography()
    demography.add_population(initial_size=(Ne))
    
    ts = msprime.sim_ancestry(
        samples=sample_size,recombination_rate=r, sequence_length=L,
        demography=demography,
        ploidy=1,
        model=model,
        random_seed=seed, num_replicates=200)
    return list(ts)

def sample_selection_coefficient():

    selection_type = np.random.choice(["strong", "medium", "weak", "none"])
    selection_coefficient = {"strong":[1, 0.1], "medium":[0.1, 0.01], "weak":[0.01, 0.001], "none": None}
    selection_coefficient_range = selection_coefficient[selection_type]

    if selection_type != "none":
        s = np.round(np.random.uniform(selection_coefficient_range[0], selection_coefficient_range[1]), 3)
        return s, selection_type
    else:
        return 0, selection_type

    
def get_kingman_model(s, L, Ne = 100_000):
    if s != 0:
        model_kingman = [msprime.SweepGenicSelection(position=(L/2), start_frequency=(1/Ne),end_frequency=0.99,s=s,dt=(1/(40*Ne))), msprime.StandardCoalescent()]
    else:
        model_kingman = [msprime.StandardCoalescent()]
        
    return model_kingman


def get_beta_model(alpha, Ne = 100_000):

    model_beta = [msprime.BetaCoalescent(alpha=alpha)]
        
    return model_beta


def get_mid_trees(ts):

    for i, tree in enumerate(ts.trees()):
        if tree.interval.left >= (ts.sequence_length/2):
            break

    first_tree = i-249
    last_tree = i + 250
    
    trees = []
    for j, tree in enumerate(ts.aslist()):
        if j >= first_tree and j <= last_tree:
            trees.append(tree)
            
    return trees

# %%
np.random.seed(0x1337)
directory = "./classification_dataset/"


for nth_scenario in range(1000):

    if nth_scenario % 2 == 0:
    
    
        L = 100_000
        s, selection_type = sample_selection_coefficient()

        model_kingman = get_kingman_model(s, L)
        tree_sequences = simulate_tree_sequence(L, model_kingman, 1+nth_scenario*10)
        num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])

        while num_ts_above_1999 < 100:
            L = L*2
            #print(L)
            model_kingman = get_kingman_model(s, L)
            tree_sequences = simulate_tree_sequence(L, model_kingman, 1+nth_scenario*10)
            num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])


        c = 0
        for j, ts in enumerate(tree_sequences):

            if ts.num_trees >= 2000 and c < 100:
                y_dict = {"model": ("kingman", None), "sequence_length":L, "selection_coefficient":s, "selection_type":selection_type}
                torch.save((ts, y_dict),  open(str(directory) + "kingman_" + str(nth_scenario) + "_" + str(j) + ".pth", "wb"))
                c += 1
                
                
    else:
        
        L = 100_000
        
        alpha = np.round(np.random.uniform(1.01, 1.99), 2)
        model_beta = get_beta_model(alpha)
        tree_sequences = simulate_tree_sequence(L, model_beta, 1+nth_scenario*10)
        num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])

        while num_ts_above_1999 < 100:
            L = L*2
            #print(L, num_ts_above_1999)
            model_beta = get_beta_model(alpha)
            tree_sequences = simulate_tree_sequence(L, model_beta, 1+nth_scenario*10)
            num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])


        c = 0
        for j, ts in enumerate(tree_sequences):

            if ts.num_trees >= 2000 and c < 100:
                y_dict = {"model": ("beta", alpha), "sequence_length":L, "selection_coefficient":0, "selection_type":None}
                torch.save((ts, y_dict),  open(str(directory) + "beta_" + str(nth_scenario) + "_" + str(j) + ".pth", "wb"))
                c += 1

    print(nth_scenario, y_dict)
# Out:
# 0 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.041, 'selection_type': 'medium'}
# 1 {'model': ('beta', 1.86), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 2 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.061, 'selection_type': 'medium'}
# 3 {'model': ('beta', 1.25), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 4 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.346, 'selection_type': 'strong'}
# 5 {'model': ('beta', 1.84), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 6 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 7 {'model': ('beta', 1.26), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 8 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 9 {'model': ('beta', 1.57), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 10 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.995, 'selection_type': 'strong'}
# 11 {'model': ('beta', 1.95), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 12 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.055, 'selection_type': 'medium'}
# 13 {'model': ('beta', 1.9), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 14 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 15 {'model': ('beta', 1.88), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 16 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.394, 'selection_type': 'strong'}
# 17 {'model': ('beta', 1.03), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 18 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 19 {'model': ('beta', 1.42), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 20 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 21 {'model': ('beta', 1.11), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 22 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.079, 'selection_type': 'medium'}
# 23 {'model': ('beta', 1.34), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 24 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.276, 'selection_type': 'strong'}
# 25 {'model': ('beta', 1.39), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 26 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.053, 'selection_type': 'medium'}
# 27 {'model': ('beta', 1.79), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 28 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.321, 'selection_type': 'strong'}
# 29 {'model': ('beta', 1.13), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 30 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 31 {'model': ('beta', 1.89), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 32 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.01, 'selection_type': 'weak'}
# 33 {'model': ('beta', 1.74), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 34 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.607, 'selection_type': 'strong'}
# 35 {'model': ('beta', 1.76), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 36 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 37 {'model': ('beta', 1.21), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 38 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 39 {'model': ('beta', 1.65), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 40 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 41 {'model': ('beta', 1.69), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 42 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.048, 'selection_type': 'medium'}
# 43 {'model': ('beta', 1.33), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 44 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.097, 'selection_type': 'medium'}
# 45 {'model': ('beta', 1.74), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 46 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.02, 'selection_type': 'medium'}
# 47 {'model': ('beta', 1.24), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 48 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 49 {'model': ('beta', 1.63), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 50 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.037, 'selection_type': 'medium'}
# 51 {'model': ('beta', 1.76), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 52 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.975, 'selection_type': 'strong'}
# 53 {'model': ('beta', 1.08), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 54 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.045, 'selection_type': 'medium'}
# 55 {'model': ('beta', 1.52), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 56 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 57 {'model': ('beta', 1.79), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 58 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.052, 'selection_type': 'medium'}
# 59 {'model': ('beta', 1.66), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 60 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 61 {'model': ('beta', 1.74), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 62 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 63 {'model': ('beta', 1.38), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 64 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.031, 'selection_type': 'medium'}
# 65 {'model': ('beta', 1.91), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 66 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 67 {'model': ('beta', 1.16), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 68 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.567, 'selection_type': 'strong'}
# 69 {'model': ('beta', 1.33), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 70 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.04, 'selection_type': 'medium'}
# 71 {'model': ('beta', 1.46), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 72 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 73 {'model': ('beta', 1.9), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 74 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.692, 'selection_type': 'strong'}
# 75 {'model': ('beta', 1.37), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 76 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.249, 'selection_type': 'strong'}
# 77 {'model': ('beta', 1.3), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 78 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 79 {'model': ('beta', 1.38), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 80 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 81 {'model': ('beta', 1.28), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 82 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 83 {'model': ('beta', 1.13), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 84 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 85 {'model': ('beta', 1.24), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 86 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 87 {'model': ('beta', 1.98), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 88 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.019, 'selection_type': 'medium'}
# 89 {'model': ('beta', 1.17), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 90 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 91 {'model': ('beta', 1.34), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 92 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 93 {'model': ('beta', 1.35), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 94 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 95 {'model': ('beta', 1.13), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 96 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.451, 'selection_type': 'strong'}
# 97 {'model': ('beta', 1.13), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 98 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.797, 'selection_type': 'strong'}
# 99 {'model': ('beta', 1.39), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 100 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 101 {'model': ('beta', 1.61), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 102 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.888, 'selection_type': 'strong'}
# 103 {'model': ('beta', 1.26), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 104 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.087, 'selection_type': 'medium'}
# 105 {'model': ('beta', 1.32), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 106 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 107 {'model': ('beta', 1.94), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 108 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.739, 'selection_type': 'strong'}
# 109 {'model': ('beta', 1.27), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 110 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.08, 'selection_type': 'medium'}
# 111 {'model': ('beta', 1.35), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 112 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.677, 'selection_type': 'strong'}
# 113 {'model': ('beta', 1.46), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 114 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 115 {'model': ('beta', 1.51), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 116 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.095, 'selection_type': 'medium'}
# 117 {'model': ('beta', 1.71), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 118 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.054, 'selection_type': 'medium'}
# 119 {'model': ('beta', 1.48), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 120 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.041, 'selection_type': 'medium'}
# 121 {'model': ('beta', 1.03), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 122 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.008, 'selection_type': 'weak'}
# 123 {'model': ('beta', 1.13), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 124 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.06, 'selection_type': 'medium'}
# 125 {'model': ('beta', 1.68), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 126 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.661, 'selection_type': 'strong'}
# 127 {'model': ('beta', 1.96), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 128 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 129 {'model': ('beta', 1.23), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 130 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 131 {'model': ('beta', 1.67), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 132 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.025, 'selection_type': 'medium'}
# 133 {'model': ('beta', 1.2), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 134 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.114, 'selection_type': 'strong'}
# 135 {'model': ('beta', 1.9), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 136 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 137 {'model': ('beta', 1.42), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 138 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 139 {'model': ('beta', 1.04), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 140 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.91, 'selection_type': 'strong'}
# 141 {'model': ('beta', 1.92), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 142 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.892, 'selection_type': 'strong'}
# 143 {'model': ('beta', 1.27), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 144 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 145 {'model': ('beta', 1.46), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 146 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 147 {'model': ('beta', 1.38), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 148 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 149 {'model': ('beta', 1.12), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 150 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 151 {'model': ('beta', 1.21), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 152 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 153 {'model': ('beta', 1.46), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 154 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.357, 'selection_type': 'strong'}
# 155 {'model': ('beta', 1.08), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 156 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 157 {'model': ('beta', 1.03), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 158 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.278, 'selection_type': 'strong'}
# 159 {'model': ('beta', 1.64), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 160 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.848, 'selection_type': 'strong'}
# 161 {'model': ('beta', 1.63), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 162 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 163 {'model': ('beta', 1.94), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 164 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 165 {'model': ('beta', 1.06), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 166 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.064, 'selection_type': 'medium'}
# 167 {'model': ('beta', 1.59), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 168 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.04, 'selection_type': 'medium'}
# 169 {'model': ('beta', 1.02), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 170 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.313, 'selection_type': 'strong'}
# 171 {'model': ('beta', 1.12), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 172 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 173 {'model': ('beta', 1.1), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 174 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 175 {'model': ('beta', 1.58), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 176 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.09, 'selection_type': 'medium'}
# 177 {'model': ('beta', 1.63), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 178 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.044, 'selection_type': 'medium'}
# 179 {'model': ('beta', 1.57), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 180 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.931, 'selection_type': 'strong'}
# 181 {'model': ('beta', 1.89), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 182 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 183 {'model': ('beta', 1.44), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 184 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.03, 'selection_type': 'medium'}
# 185 {'model': ('beta', 1.35), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 186 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 187 {'model': ('beta', 1.28), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 188 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 189 {'model': ('beta', 1.3), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 190 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 191 {'model': ('beta', 1.65), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 192 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.667, 'selection_type': 'strong'}
# 193 {'model': ('beta', 1.8), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 194 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 195 {'model': ('beta', 1.91), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 196 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 197 {'model': ('beta', 1.45), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 198 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.174, 'selection_type': 'strong'}
# 199 {'model': ('beta', 1.2), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 200 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 201 {'model': ('beta', 1.03), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 202 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 203 {'model': ('beta', 1.26), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 204 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 205 {'model': ('beta', 1.04), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 206 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 207 {'model': ('beta', 1.15), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 208 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.913, 'selection_type': 'strong'}
# 209 {'model': ('beta', 1.38), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 210 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.085, 'selection_type': 'medium'}
# 211 {'model': ('beta', 1.51), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 212 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 213 {'model': ('beta', 1.3), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 214 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.04, 'selection_type': 'medium'}
# 215 {'model': ('beta', 1.14), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 216 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.482, 'selection_type': 'strong'}
# 217 {'model': ('beta', 1.41), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 218 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.07, 'selection_type': 'medium'}
# 219 {'model': ('beta', 1.3), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 220 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 221 {'model': ('beta', 1.95), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 222 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.072, 'selection_type': 'medium'}
# 223 {'model': ('beta', 1.2), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 224 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.598, 'selection_type': 'strong'}
# 225 {'model': ('beta', 1.9), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 226 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.686, 'selection_type': 'strong'}
# 227 {'model': ('beta', 1.19), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 228 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.822, 'selection_type': 'strong'}
# 229 {'model': ('beta', 1.45), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 230 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.93, 'selection_type': 'strong'}
# 231 {'model': ('beta', 1.78), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 232 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.097, 'selection_type': 'medium'}
# 233 {'model': ('beta', 1.93), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 234 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.311, 'selection_type': 'strong'}
# 235 {'model': ('beta', 1.81), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 236 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.658, 'selection_type': 'strong'}
# 237 {'model': ('beta', 1.43), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 238 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 239 {'model': ('beta', 1.5), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 240 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.066, 'selection_type': 'medium'}
# 241 {'model': ('beta', 1.49), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 242 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.051, 'selection_type': 'medium'}
# 243 {'model': ('beta', 1.65), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 244 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.03, 'selection_type': 'medium'}
# 245 {'model': ('beta', 1.83), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 246 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 247 {'model': ('beta', 1.16), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 248 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 249 {'model': ('beta', 1.03), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 250 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 251 {'model': ('beta', 1.92), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 252 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 253 {'model': ('beta', 1.96), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 254 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.397, 'selection_type': 'strong'}
# 255 {'model': ('beta', 1.05), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 256 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.008, 'selection_type': 'weak'}
# 257 {'model': ('beta', 1.1), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 258 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.676, 'selection_type': 'strong'}
# 259 {'model': ('beta', 1.5), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 260 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.035, 'selection_type': 'medium'}
# 261 {'model': ('beta', 1.85), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 262 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.378, 'selection_type': 'strong'}
# 263 {'model': ('beta', 1.1), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 264 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.245, 'selection_type': 'strong'}
# 265 {'model': ('beta', 1.8), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 266 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.452, 'selection_type': 'strong'}
# 267 {'model': ('beta', 1.48), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 268 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 269 {'model': ('beta', 1.9), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 270 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.039, 'selection_type': 'medium'}
# 271 {'model': ('beta', 1.73), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 272 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.019, 'selection_type': 'medium'}
# 273 {'model': ('beta', 1.62), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 274 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.458, 'selection_type': 'strong'}
# 275 {'model': ('beta', 1.27), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 276 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 277 {'model': ('beta', 1.94), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 278 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 279 {'model': ('beta', 1.63), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 280 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.017, 'selection_type': 'medium'}
# 281 {'model': ('beta', 1.12), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 282 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.04, 'selection_type': 'medium'}
# 283 {'model': ('beta', 1.62), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 284 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 285 {'model': ('beta', 1.95), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 286 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.479, 'selection_type': 'strong'}
# 287 {'model': ('beta', 1.95), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 288 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.029, 'selection_type': 'medium'}
# 289 {'model': ('beta', 1.24), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 290 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 291 {'model': ('beta', 1.69), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 292 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 293 {'model': ('beta', 1.3), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 294 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.45, 'selection_type': 'strong'}
# 295 {'model': ('beta', 1.96), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 296 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 297 {'model': ('beta', 1.05), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 298 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 299 {'model': ('beta', 1.98), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 300 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 301 {'model': ('beta', 1.19), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 302 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.667, 'selection_type': 'strong'}
# 303 {'model': ('beta', 1.4), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 304 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.095, 'selection_type': 'medium'}
# 305 {'model': ('beta', 1.24), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 306 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 307 {'model': ('beta', 1.52), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 308 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.05, 'selection_type': 'medium'}
# 309 {'model': ('beta', 1.69), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 310 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 311 {'model': ('beta', 1.13), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 312 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 313 {'model': ('beta', 1.55), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 314 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 315 {'model': ('beta', 1.52), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 316 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.766, 'selection_type': 'strong'}
# 317 {'model': ('beta', 1.42), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 318 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.058, 'selection_type': 'medium'}
# 319 {'model': ('beta', 1.95), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 320 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.757, 'selection_type': 'strong'}
# 321 {'model': ('beta', 1.73), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 322 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 323 {'model': ('beta', 1.69), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 324 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 325 {'model': ('beta', 1.36), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 326 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.095, 'selection_type': 'medium'}
# 327 {'model': ('beta', 1.05), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 328 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 329 {'model': ('beta', 1.18), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 330 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 331 {'model': ('beta', 1.21), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 332 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.693, 'selection_type': 'strong'}
# 333 {'model': ('beta', 1.13), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 334 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.524, 'selection_type': 'strong'}
# 335 {'model': ('beta', 1.04), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 336 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.193, 'selection_type': 'strong'}
# 337 {'model': ('beta', 1.87), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 338 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 339 {'model': ('beta', 1.73), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 340 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.08, 'selection_type': 'medium'}
# 341 {'model': ('beta', 1.15), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 342 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 343 {'model': ('beta', 1.73), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 344 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.052, 'selection_type': 'medium'}
# 345 {'model': ('beta', 1.4), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 346 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 347 {'model': ('beta', 1.4), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 348 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.01, 'selection_type': 'weak'}
# 349 {'model': ('beta', 1.82), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 350 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 351 {'model': ('beta', 1.93), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 352 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.23, 'selection_type': 'strong'}
# 353 {'model': ('beta', 1.21), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 354 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 355 {'model': ('beta', 1.37), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 356 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.919, 'selection_type': 'strong'}
# 357 {'model': ('beta', 1.53), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 358 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.008, 'selection_type': 'weak'}
# 359 {'model': ('beta', 1.72), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 360 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.027, 'selection_type': 'medium'}
# 361 {'model': ('beta', 1.13), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 362 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.014, 'selection_type': 'medium'}
# 363 {'model': ('beta', 1.45), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 364 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 365 {'model': ('beta', 1.81), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 366 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 367 {'model': ('beta', 1.73), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 368 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.65, 'selection_type': 'strong'}
# 369 {'model': ('beta', 1.38), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 370 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.049, 'selection_type': 'medium'}
# 371 {'model': ('beta', 1.64), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 372 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.053, 'selection_type': 'medium'}
# 373 {'model': ('beta', 1.22), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 374 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 375 {'model': ('beta', 1.13), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 376 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.918, 'selection_type': 'strong'}
# 377 {'model': ('beta', 1.67), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 378 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.898, 'selection_type': 'strong'}
# 379 {'model': ('beta', 1.36), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 380 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.04, 'selection_type': 'medium'}
# 381 {'model': ('beta', 1.24), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 382 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.407, 'selection_type': 'strong'}
# 383 {'model': ('beta', 1.14), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 384 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.853, 'selection_type': 'strong'}
# 385 {'model': ('beta', 1.28), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 386 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.01, 'selection_type': 'weak'}
# 387 {'model': ('beta', 1.82), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 388 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.043, 'selection_type': 'medium'}
# 389 {'model': ('beta', 1.47), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 390 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 391 {'model': ('beta', 1.49), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 392 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 393 {'model': ('beta', 1.53), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 394 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 395 {'model': ('beta', 1.51), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 396 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.747, 'selection_type': 'strong'}
# 397 {'model': ('beta', 1.58), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 398 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.01, 'selection_type': 'weak'}
# 399 {'model': ('beta', 1.09), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 400 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 401 {'model': ('beta', 1.16), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 402 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 403 {'model': ('beta', 1.47), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 404 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.024, 'selection_type': 'medium'}
# 405 {'model': ('beta', 1.56), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 406 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 407 {'model': ('beta', 1.97), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 408 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 409 {'model': ('beta', 1.46), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 410 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.576, 'selection_type': 'strong'}
# 411 {'model': ('beta', 1.95), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 412 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 413 {'model': ('beta', 1.69), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 414 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.067, 'selection_type': 'medium'}
# 415 {'model': ('beta', 1.69), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 416 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.01, 'selection_type': 'weak'}
# ...
# 794 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.037, 'selection_type': 'medium'}
# 795 {'model': ('beta', 1.1), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 796 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 797 {'model': ('beta', 1.15), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 798 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.053, 'selection_type': 'medium'}
# 799 {'model': ('beta', 1.69), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 800 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.065, 'selection_type': 'medium'}
# 801 {'model': ('beta', 1.37), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 802 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 803 {'model': ('beta', 1.56), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 804 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.008, 'selection_type': 'weak'}
# 805 {'model': ('beta', 1.51), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 806 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.057, 'selection_type': 'medium'}
# 807 {'model': ('beta', 1.92), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 808 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 809 {'model': ('beta', 1.87), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 810 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.568, 'selection_type': 'strong'}
# 811 {'model': ('beta', 1.68), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 812 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 813 {'model': ('beta', 1.03), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 814 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 815 {'model': ('beta', 1.67), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 816 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.027, 'selection_type': 'medium'}
# 817 {'model': ('beta', 1.59), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 818 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.06, 'selection_type': 'medium'}
# 819 {'model': ('beta', 1.6), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 820 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 821 {'model': ('beta', 1.75), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 822 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.517, 'selection_type': 'strong'}
# 823 {'model': ('beta', 1.72), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 824 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.065, 'selection_type': 'medium'}
# 825 {'model': ('beta', 1.18), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 826 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 827 {'model': ('beta', 1.61), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 828 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.051, 'selection_type': 'medium'}
# 829 {'model': ('beta', 1.15), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 830 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.203, 'selection_type': 'strong'}
# 831 {'model': ('beta', 1.41), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 832 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 833 {'model': ('beta', 1.14), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 834 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.756, 'selection_type': 'strong'}
# 835 {'model': ('beta', 1.08), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 836 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.525, 'selection_type': 'strong'}
# 837 {'model': ('beta', 1.1), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 838 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.01, 'selection_type': 'weak'}
# 839 {'model': ('beta', 1.67), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 840 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 841 {'model': ('beta', 1.19), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 842 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.67, 'selection_type': 'strong'}
# 843 {'model': ('beta', 1.35), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 844 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 845 {'model': ('beta', 1.82), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 846 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 847 {'model': ('beta', 1.49), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 848 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.013, 'selection_type': 'medium'}
# 849 {'model': ('beta', 1.04), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 850 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.838, 'selection_type': 'strong'}
# 851 {'model': ('beta', 1.05), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 852 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 853 {'model': ('beta', 1.24), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 854 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.523, 'selection_type': 'strong'}
# 855 {'model': ('beta', 1.78), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 856 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.673, 'selection_type': 'strong'}
# 857 {'model': ('beta', 1.78), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 858 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.94, 'selection_type': 'strong'}
# 859 {'model': ('beta', 1.84), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 860 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.036, 'selection_type': 'medium'}
# 861 {'model': ('beta', 1.83), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 862 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.602, 'selection_type': 'strong'}
# 863 {'model': ('beta', 1.86), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 864 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 865 {'model': ('beta', 1.25), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 866 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 867 {'model': ('beta', 1.94), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 868 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.808, 'selection_type': 'strong'}
# 869 {'model': ('beta', 1.29), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 870 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.036, 'selection_type': 'medium'}
# 871 {'model': ('beta', 1.83), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 872 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.093, 'selection_type': 'medium'}
# 873 {'model': ('beta', 1.12), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 874 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.321, 'selection_type': 'strong'}
# 875 {'model': ('beta', 1.19), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 876 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.048, 'selection_type': 'medium'}
# 877 {'model': ('beta', 1.62), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 878 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 879 {'model': ('beta', 1.38), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 880 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.099, 'selection_type': 'medium'}
# 881 {'model': ('beta', 1.37), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 882 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.772, 'selection_type': 'strong'}
# 883 {'model': ('beta', 1.67), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 884 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 885 {'model': ('beta', 1.45), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 886 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.325, 'selection_type': 'strong'}
# 887 {'model': ('beta', 1.13), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 888 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.041, 'selection_type': 'medium'}
# 889 {'model': ('beta', 1.75), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 890 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 891 {'model': ('beta', 1.84), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 892 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.535, 'selection_type': 'strong'}
# 893 {'model': ('beta', 1.42), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 894 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.285, 'selection_type': 'strong'}
# 895 {'model': ('beta', 1.19), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 896 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 897 {'model': ('beta', 1.22), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 898 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.031, 'selection_type': 'medium'}
# 899 {'model': ('beta', 1.23), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 900 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.621, 'selection_type': 'strong'}
# 901 {'model': ('beta', 1.84), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 902 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 903 {'model': ('beta', 1.62), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 904 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.056, 'selection_type': 'medium'}
# 905 {'model': ('beta', 1.33), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 906 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 907 {'model': ('beta', 1.91), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 908 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.808, 'selection_type': 'strong'}
# 909 {'model': ('beta', 1.59), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 910 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 911 {'model': ('beta', 1.04), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 912 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 913 {'model': ('beta', 1.24), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 914 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.039, 'selection_type': 'medium'}
# 915 {'model': ('beta', 1.05), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 916 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.081, 'selection_type': 'medium'}
# 917 {'model': ('beta', 1.43), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 918 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.838, 'selection_type': 'strong'}
# 919 {'model': ('beta', 1.69), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 920 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 921 {'model': ('beta', 1.47), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 922 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.145, 'selection_type': 'strong'}
# 923 {'model': ('beta', 1.15), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': None}
# 924 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 925 {'model': ('beta', 1.67), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 926 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 927 {'model': ('beta', 1.2), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 928 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.01, 'selection_type': 'weak'}
# 929 {'model': ('beta', 1.34), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 930 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 931 {'model': ('beta', 1.49), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}

# %%
np.random.seed(0x999999)
directory = "./validation_classification_dataset/"


for nth_scenario in range(10000):

    if nth_scenario % 2 == 0:
    
    
        L = 100_000
        s, selection_type = sample_selection_coefficient()

        model_kingman = get_kingman_model(s, L)
        tree_sequences = simulate_tree_sequence(L, model_kingman, 1+nth_scenario*10)
        num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])

        while num_ts_above_1999 < 1:
            L = L*2
            #print(L)
            model_kingman = get_kingman_model(s, L)
            tree_sequences = simulate_tree_sequence(L, model_kingman, 1+nth_scenario*10)
            num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])


        c = 0
        for j, ts in enumerate(tree_sequences):

            if ts.num_trees >= 2000 and c < 1:
                y_dict = {"model": ("kingman", None), "sequence_length":L, "selection_coefficient":s, "selection_type":selection_type}
                torch.save((ts, y_dict),  open(str(directory) + "kingman_" + str(nth_scenario) + "_" + str(j) + ".pth", "wb"))
                c += 1
                
    else:
        
        L = 100_000
        
        alpha = np.round(np.random.uniform(1.01, 1.99), 2)
        model_beta = get_beta_model(alpha)
        tree_sequences = simulate_tree_sequence(L, model_beta, 1+nth_scenario*10)
        num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])

        while num_ts_above_1999 < 1:
            L = L*2
            #print(L, num_ts_above_1999)
            model_beta = get_beta_model(alpha)
            tree_sequences = simulate_tree_sequence(L, model_beta, 1+nth_scenario*10)
            num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])


        c = 0
        for j, ts in enumerate(tree_sequences):

            if ts.num_trees >= 2000 and c < 1:
                y_dict = {"model": ("beta", alpha), "sequence_length":L, "selection_coefficient":0, "selection_type":None}
                torch.save((ts, y_dict),  open(str(directory) + "beta_" + str(nth_scenario) + "_" + str(j) + ".pth", "wb"))
                c += 1

    print(nth_scenario, y_dict)
# Out:
# 0 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.751, 'selection_type': 'strong'}
# 1 {'model': ('beta', 1.84), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 2 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 3 {'model': ('beta', 1.07), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 4 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.036, 'selection_type': 'medium'}
# 5 {'model': ('beta', 1.38), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 6 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.053, 'selection_type': 'medium'}
# 7 {'model': ('beta', 1.27), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 8 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.069, 'selection_type': 'medium'}
# 9 {'model': ('beta', 1.96), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 10 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 11 {'model': ('beta', 1.58), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 12 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.01, 'selection_type': 'weak'}
# 13 {'model': ('beta', 1.34), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 14 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.688, 'selection_type': 'strong'}
# 15 {'model': ('beta', 1.38), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 16 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 17 {'model': ('beta', 1.84), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 18 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.593, 'selection_type': 'strong'}
# 19 {'model': ('beta', 1.97), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 20 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 21 {'model': ('beta', 1.34), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 22 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.631, 'selection_type': 'strong'}
# 23 {'model': ('beta', 1.49), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 24 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 25 {'model': ('beta', 1.35), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 26 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.074, 'selection_type': 'medium'}
# 27 {'model': ('beta', 1.44), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 28 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.083, 'selection_type': 'medium'}
# 29 {'model': ('beta', 1.66), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 30 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 31 {'model': ('beta', 1.14), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 32 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 33 {'model': ('beta', 1.11), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 34 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 35 {'model': ('beta', 1.96), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 36 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.049, 'selection_type': 'medium'}
# 37 {'model': ('beta', 1.53), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 38 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.065, 'selection_type': 'medium'}
# 39 {'model': ('beta', 1.25), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 40 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.064, 'selection_type': 'medium'}
# 41 {'model': ('beta', 1.48), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 42 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.611, 'selection_type': 'strong'}
# 43 {'model': ('beta', 1.03), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 44 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.347, 'selection_type': 'strong'}
# 45 {'model': ('beta', 1.21), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 46 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.084, 'selection_type': 'medium'}
# 47 {'model': ('beta', 1.02), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 48 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.066, 'selection_type': 'medium'}
# 49 {'model': ('beta', 1.25), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 50 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 51 {'model': ('beta', 1.61), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 52 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 53 {'model': ('beta', 1.76), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 54 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.726, 'selection_type': 'strong'}
# 55 {'model': ('beta', 1.62), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 56 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.735, 'selection_type': 'strong'}
# 57 {'model': ('beta', 1.3), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 58 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 59 {'model': ('beta', 1.71), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 60 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.043, 'selection_type': 'medium'}
# 61 {'model': ('beta', 1.6), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 62 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.04, 'selection_type': 'medium'}
# 63 {'model': ('beta', 1.3), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 64 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.051, 'selection_type': 'medium'}
# 65 {'model': ('beta', 1.31), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 66 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.094, 'selection_type': 'medium'}
# 67 {'model': ('beta', 1.82), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 68 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 69 {'model': ('beta', 1.25), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 70 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 71 {'model': ('beta', 1.1), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 72 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.15, 'selection_type': 'strong'}
# 73 {'model': ('beta', 1.41), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 74 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.508, 'selection_type': 'strong'}
# 75 {'model': ('beta', 1.95), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 76 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.031, 'selection_type': 'medium'}
# 77 {'model': ('beta', 1.45), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 78 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 79 {'model': ('beta', 1.97), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 80 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 81 {'model': ('beta', 1.13), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 82 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 83 {'model': ('beta', 1.86), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 84 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 85 {'model': ('beta', 1.06), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 86 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 87 {'model': ('beta', 1.9), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 88 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 89 {'model': ('beta', 1.85), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 90 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.082, 'selection_type': 'medium'}
# 91 {'model': ('beta', 1.52), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 92 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 93 {'model': ('beta', 1.14), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 94 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 95 {'model': ('beta', 1.1), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 96 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 97 {'model': ('beta', 1.95), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 98 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.053, 'selection_type': 'medium'}
# 99 {'model': ('beta', 1.27), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 100 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 101 {'model': ('beta', 1.62), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 102 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.072, 'selection_type': 'medium'}
# 103 {'model': ('beta', 1.11), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 104 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 105 {'model': ('beta', 1.8), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 106 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.064, 'selection_type': 'medium'}
# 107 {'model': ('beta', 1.49), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 108 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.296, 'selection_type': 'strong'}
# 109 {'model': ('beta', 1.36), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 110 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.062, 'selection_type': 'medium'}
# 111 {'model': ('beta', 1.63), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 112 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.026, 'selection_type': 'medium'}
# 113 {'model': ('beta', 1.33), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 114 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.349, 'selection_type': 'strong'}
# 115 {'model': ('beta', 1.98), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 116 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 117 {'model': ('beta', 1.45), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 118 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.527, 'selection_type': 'strong'}
# 119 {'model': ('beta', 1.96), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 120 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.093, 'selection_type': 'medium'}
# 121 {'model': ('beta', 1.77), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 122 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 123 {'model': ('beta', 1.13), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 124 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 125 {'model': ('beta', 1.1), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 126 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.008, 'selection_type': 'weak'}
# 127 {'model': ('beta', 1.84), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 128 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.664, 'selection_type': 'strong'}
# 129 {'model': ('beta', 1.9), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 130 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.075, 'selection_type': 'medium'}
# 131 {'model': ('beta', 1.65), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 132 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 133 {'model': ('beta', 1.86), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 134 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.023, 'selection_type': 'medium'}
# 135 {'model': ('beta', 1.26), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 136 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 137 {'model': ('beta', 1.14), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 138 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.467, 'selection_type': 'strong'}
# 139 {'model': ('beta', 1.11), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 140 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 141 {'model': ('beta', 1.73), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 142 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.041, 'selection_type': 'medium'}
# 143 {'model': ('beta', 1.41), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 144 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.085, 'selection_type': 'medium'}
# 145 {'model': ('beta', 1.17), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 146 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 147 {'model': ('beta', 1.14), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 148 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.013, 'selection_type': 'medium'}
# 149 {'model': ('beta', 1.17), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 150 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.278, 'selection_type': 'strong'}
# 151 {'model': ('beta', 1.82), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 152 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 153 {'model': ('beta', 1.16), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 154 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 155 {'model': ('beta', 1.18), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 156 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.06, 'selection_type': 'medium'}
# 157 {'model': ('beta', 1.3), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 158 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.088, 'selection_type': 'medium'}
# 159 {'model': ('beta', 1.5), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 160 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 161 {'model': ('beta', 1.9), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 162 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.008, 'selection_type': 'weak'}
# 163 {'model': ('beta', 1.45), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 164 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 165 {'model': ('beta', 1.2), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 166 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 167 {'model': ('beta', 1.76), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 168 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.777, 'selection_type': 'strong'}
# 169 {'model': ('beta', 1.51), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 170 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 171 {'model': ('beta', 1.64), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 172 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 173 {'model': ('beta', 1.04), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 174 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 175 {'model': ('beta', 1.77), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 176 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.587, 'selection_type': 'strong'}
# 177 {'model': ('beta', 1.73), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 178 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.016, 'selection_type': 'medium'}
# 179 {'model': ('beta', 1.6), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 180 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.073, 'selection_type': 'medium'}
# 181 {'model': ('beta', 1.23), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 182 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 183 {'model': ('beta', 1.88), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 184 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.824, 'selection_type': 'strong'}
# 185 {'model': ('beta', 1.25), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 186 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 187 {'model': ('beta', 1.95), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 188 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 189 {'model': ('beta', 1.31), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 190 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 191 {'model': ('beta', 1.52), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 192 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 193 {'model': ('beta', 1.73), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 194 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 195 {'model': ('beta', 1.7), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 196 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.287, 'selection_type': 'strong'}
# 197 {'model': ('beta', 1.73), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 198 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.026, 'selection_type': 'medium'}
# 199 {'model': ('beta', 1.22), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 200 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 201 {'model': ('beta', 1.71), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 202 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.079, 'selection_type': 'medium'}
# 203 {'model': ('beta', 1.53), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 204 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.769, 'selection_type': 'strong'}
# 205 {'model': ('beta', 1.66), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 206 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.514, 'selection_type': 'strong'}
# 207 {'model': ('beta', 1.32), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 208 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 209 {'model': ('beta', 1.93), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 210 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.597, 'selection_type': 'strong'}
# 211 {'model': ('beta', 1.51), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 212 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.391, 'selection_type': 'strong'}
# 213 {'model': ('beta', 1.73), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 214 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 215 {'model': ('beta', 1.86), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 216 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.666, 'selection_type': 'strong'}
# 217 {'model': ('beta', 1.51), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 218 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.061, 'selection_type': 'medium'}
# 219 {'model': ('beta', 1.31), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 220 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 221 {'model': ('beta', 1.22), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 222 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.316, 'selection_type': 'strong'}
# 223 {'model': ('beta', 1.33), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 224 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.088, 'selection_type': 'medium'}
# 225 {'model': ('beta', 1.37), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 226 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.034, 'selection_type': 'medium'}
# 227 {'model': ('beta', 1.77), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 228 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.368, 'selection_type': 'strong'}
# 229 {'model': ('beta', 1.43), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 230 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.025, 'selection_type': 'medium'}
# 231 {'model': ('beta', 1.12), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 232 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.694, 'selection_type': 'strong'}
# 233 {'model': ('beta', 1.33), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 234 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.069, 'selection_type': 'medium'}
# 235 {'model': ('beta', 1.27), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 236 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 237 {'model': ('beta', 1.84), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 238 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.047, 'selection_type': 'medium'}
# 239 {'model': ('beta', 1.91), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 240 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 241 {'model': ('beta', 1.73), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 242 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.075, 'selection_type': 'medium'}
# 243 {'model': ('beta', 1.79), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 244 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 245 {'model': ('beta', 1.26), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 246 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.899, 'selection_type': 'strong'}
# 247 {'model': ('beta', 1.89), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 248 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.068, 'selection_type': 'medium'}
# 249 {'model': ('beta', 1.81), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 250 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.511, 'selection_type': 'strong'}
# 251 {'model': ('beta', 1.69), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 252 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 253 {'model': ('beta', 1.25), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 254 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.346, 'selection_type': 'strong'}
# 255 {'model': ('beta', 1.97), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 256 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.401, 'selection_type': 'strong'}
# 257 {'model': ('beta', 1.19), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 258 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.034, 'selection_type': 'medium'}
# 259 {'model': ('beta', 1.25), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 260 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.087, 'selection_type': 'medium'}
# 261 {'model': ('beta', 1.59), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 262 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 263 {'model': ('beta', 1.47), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 264 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 265 {'model': ('beta', 1.33), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 266 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.027, 'selection_type': 'medium'}
# 267 {'model': ('beta', 1.27), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 268 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.435, 'selection_type': 'strong'}
# 269 {'model': ('beta', 1.93), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 270 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 271 {'model': ('beta', 1.49), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 272 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 273 {'model': ('beta', 1.35), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 274 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 275 {'model': ('beta', 1.63), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 276 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.84, 'selection_type': 'strong'}
# 277 {'model': ('beta', 1.64), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 278 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 279 {'model': ('beta', 1.27), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 280 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 281 {'model': ('beta', 1.08), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 282 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 283 {'model': ('beta', 1.3), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 284 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.914, 'selection_type': 'strong'}
# 285 {'model': ('beta', 1.64), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 286 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.063, 'selection_type': 'medium'}
# 287 {'model': ('beta', 1.39), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 288 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 289 {'model': ('beta', 1.06), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 290 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 291 {'model': ('beta', 1.99), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 292 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.054, 'selection_type': 'medium'}
# 293 {'model': ('beta', 1.95), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 294 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 295 {'model': ('beta', 1.5), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 296 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.023, 'selection_type': 'medium'}
# 297 {'model': ('beta', 1.66), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 298 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 299 {'model': ('beta', 1.62), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 300 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 301 {'model': ('beta', 1.11), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 302 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 303 {'model': ('beta', 1.6), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 304 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.811, 'selection_type': 'strong'}
# 305 {'model': ('beta', 1.89), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 306 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.01, 'selection_type': 'weak'}
# 307 {'model': ('beta', 1.94), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 308 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.015, 'selection_type': 'medium'}
# 309 {'model': ('beta', 1.14), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 310 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 311 {'model': ('beta', 1.42), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 312 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.098, 'selection_type': 'medium'}
# 313 {'model': ('beta', 1.92), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 314 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.334, 'selection_type': 'strong'}
# 315 {'model': ('beta', 1.17), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 316 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.008, 'selection_type': 'weak'}
# 317 {'model': ('beta', 1.67), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 318 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 319 {'model': ('beta', 1.63), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 320 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 321 {'model': ('beta', 1.8), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 322 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.356, 'selection_type': 'strong'}
# 323 {'model': ('beta', 1.92), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 324 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.852, 'selection_type': 'strong'}
# 325 {'model': ('beta', 1.85), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 326 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.758, 'selection_type': 'strong'}
# 327 {'model': ('beta', 1.07), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 328 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.553, 'selection_type': 'strong'}
# 329 {'model': ('beta', 1.14), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 330 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.386, 'selection_type': 'strong'}
# 331 {'model': ('beta', 1.8), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 332 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.854, 'selection_type': 'strong'}
# 333 {'model': ('beta', 1.47), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 334 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 335 {'model': ('beta', 1.85), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 336 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.618, 'selection_type': 'strong'}
# 337 {'model': ('beta', 1.58), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 338 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 339 {'model': ('beta', 1.79), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 340 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 341 {'model': ('beta', 1.97), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 342 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 343 {'model': ('beta', 1.6), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 344 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 345 {'model': ('beta', 1.65), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 346 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 347 {'model': ('beta', 1.15), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 348 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.045, 'selection_type': 'medium'}
# 349 {'model': ('beta', 1.28), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 350 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.022, 'selection_type': 'medium'}
# 351 {'model': ('beta', 1.47), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 352 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.951, 'selection_type': 'strong'}
# 353 {'model': ('beta', 1.05), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 354 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 355 {'model': ('beta', 1.95), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 356 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 357 {'model': ('beta', 1.09), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 358 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.468, 'selection_type': 'strong'}
# 359 {'model': ('beta', 1.01), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 360 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 361 {'model': ('beta', 1.84), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 362 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.095, 'selection_type': 'medium'}
# 363 {'model': ('beta', 1.2), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 364 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.349, 'selection_type': 'strong'}
# 365 {'model': ('beta', 1.57), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 366 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.073, 'selection_type': 'medium'}
# 367 {'model': ('beta', 1.63), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 368 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 369 {'model': ('beta', 1.03), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 370 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 371 {'model': ('beta', 1.45), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 372 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.109, 'selection_type': 'strong'}
# 373 {'model': ('beta', 1.72), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 374 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.394, 'selection_type': 'strong'}
# 375 {'model': ('beta', 1.05), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 376 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.467, 'selection_type': 'strong'}
# 377 {'model': ('beta', 1.13), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 378 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 379 {'model': ('beta', 1.24), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 380 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 381 {'model': ('beta', 1.58), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 382 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 383 {'model': ('beta', 1.77), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 384 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.162, 'selection_type': 'strong'}
# 385 {'model': ('beta', 1.08), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 386 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 387 {'model': ('beta', 1.44), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 388 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.853, 'selection_type': 'strong'}
# 389 {'model': ('beta', 1.07), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 390 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.77, 'selection_type': 'strong'}
# 391 {'model': ('beta', 1.42), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 392 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 393 {'model': ('beta', 1.95), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 394 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.029, 'selection_type': 'medium'}
# 395 {'model': ('beta', 1.7), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 396 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.848, 'selection_type': 'strong'}
# 397 {'model': ('beta', 1.66), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 398 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.011, 'selection_type': 'medium'}
# 399 {'model': ('beta', 1.74), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 400 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 401 {'model': ('beta', 1.52), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 402 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 403 {'model': ('beta', 1.56), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 404 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 405 {'model': ('beta', 1.91), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 406 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.166, 'selection_type': 'strong'}
# 407 {'model': ('beta', 1.72), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 408 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 409 {'model': ('beta', 1.17), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 410 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.172, 'selection_type': 'strong'}
# 411 {'model': ('beta', 1.62), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 412 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 413 {'model': ('beta', 1.76), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 414 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 415 {'model': ('beta', 1.03), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 416 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 417 {'model': ('beta', 1.14), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 418 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# ...
# 498 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.026, 'selection_type': 'medium'}
# 499 {'model': ('beta', 1.32), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 500 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.075, 'selection_type': 'medium'}
# 501 {'model': ('beta', 1.21), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 502 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.476, 'selection_type': 'strong'}
# 503 {'model': ('beta', 1.2), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 504 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.722, 'selection_type': 'strong'}
# 505 {'model': ('beta', 1.8), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 506 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 507 {'model': ('beta', 1.07), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 508 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.054, 'selection_type': 'medium'}
# 509 {'model': ('beta', 1.85), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 510 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 511 {'model': ('beta', 1.84), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 512 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 513 {'model': ('beta', 1.32), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 514 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.184, 'selection_type': 'strong'}
# 515 {'model': ('beta', 1.19), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 516 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 517 {'model': ('beta', 1.08), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 518 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.047, 'selection_type': 'medium'}
# 519 {'model': ('beta', 1.48), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 520 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.13, 'selection_type': 'strong'}
# 521 {'model': ('beta', 1.41), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 522 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 523 {'model': ('beta', 1.69), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 524 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.073, 'selection_type': 'medium'}
# 525 {'model': ('beta', 1.36), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 526 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 527 {'model': ('beta', 1.97), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 528 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 529 {'model': ('beta', 1.11), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 530 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 531 {'model': ('beta', 1.94), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 532 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 533 {'model': ('beta', 1.63), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 534 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 535 {'model': ('beta', 1.4), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 536 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 537 {'model': ('beta', 1.25), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 538 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.265, 'selection_type': 'strong'}
# 539 {'model': ('beta', 1.94), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 540 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.236, 'selection_type': 'strong'}
# 541 {'model': ('beta', 1.29), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 542 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 543 {'model': ('beta', 1.33), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 544 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.015, 'selection_type': 'medium'}
# 545 {'model': ('beta', 1.57), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 546 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 547 {'model': ('beta', 1.51), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 548 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 549 {'model': ('beta', 1.13), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 550 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.291, 'selection_type': 'strong'}
# 551 {'model': ('beta', 1.15), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 552 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.022, 'selection_type': 'medium'}
# 553 {'model': ('beta', 1.9), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 554 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.566, 'selection_type': 'strong'}
# 555 {'model': ('beta', 1.76), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 556 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 557 {'model': ('beta', 1.58), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 558 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.667, 'selection_type': 'strong'}
# 559 {'model': ('beta', 1.25), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 560 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.816, 'selection_type': 'strong'}
# 561 {'model': ('beta', 1.19), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 562 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 563 {'model': ('beta', 1.42), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 564 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 565 {'model': ('beta', 1.23), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 566 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 567 {'model': ('beta', 1.43), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 568 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.047, 'selection_type': 'medium'}
# 569 {'model': ('beta', 1.25), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 570 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.096, 'selection_type': 'medium'}
# 571 {'model': ('beta', 1.76), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 572 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 573 {'model': ('beta', 1.97), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': None}
# 574 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.067, 'selection_type': 'medium'}
# 575 {'model': ('beta', 1.04), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 576 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 577 {'model': ('beta', 1.1), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 578 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 579 {'model': ('beta', 1.99), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 580 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.039, 'selection_type': 'medium'}
# 581 {'model': ('beta', 1.88), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 582 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.054, 'selection_type': 'medium'}
# 583 {'model': ('beta', 1.86), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 584 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.177, 'selection_type': 'strong'}
# 585 {'model': ('beta', 1.74), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 586 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 587 {'model': ('beta', 1.37), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 588 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 589 {'model': ('beta', 1.81), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 590 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 591 {'model': ('beta', 1.2), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 592 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 593 {'model': ('beta', 1.85), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 594 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.128, 'selection_type': 'strong'}
# 595 {'model': ('beta', 1.32), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 596 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.061, 'selection_type': 'medium'}
# 597 {'model': ('beta', 1.89), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 598 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 599 {'model': ('beta', 1.3), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 600 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.79, 'selection_type': 'strong'}
# 601 {'model': ('beta', 1.46), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 602 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.775, 'selection_type': 'strong'}
# 603 {'model': ('beta', 1.78), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 604 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 605 {'model': ('beta', 1.8), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 606 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 607 {'model': ('beta', 1.1), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 608 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.318, 'selection_type': 'strong'}
# 609 {'model': ('beta', 1.16), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 610 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.066, 'selection_type': 'medium'}
# 611 {'model': ('beta', 1.17), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': None}
# 612 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 613 {'model': ('beta', 1.35), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 614 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.558, 'selection_type': 'strong'}
# 615 {'model': ('beta', 1.09), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 616 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.076, 'selection_type': 'medium'}
# 617 {'model': ('beta', 1.32), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': None}
# 618 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 619 {'model': ('beta', 1.95), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 620 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 621 {'model': ('beta', 1.52), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': None}
# 622 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.092, 'selection_type': 'medium'}
# 623 {'model': ('beta', 1.42), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': None}
# 624 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 625 {'model': ('beta', 1.05), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 626 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 627 {'model': ('beta', 1.93), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': None}
# 628 {'model': ('kingman', None), 'sequence_length': 400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 629 {'model': ('beta', 1.06), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 630 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 631 {'model': ('beta', 1.15), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 632 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.031, 'selection_type': 'medium'}
# 633 {'model': ('beta', 1.1), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 634 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.051, 'selection_type': 'medium'}
# 635 {'model': ('beta', 1.09), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': None}
# 636 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
