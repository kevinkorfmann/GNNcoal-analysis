# %%
import msprime
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import torch
# %matplotlib inline

# %%
def simulate_tree_sequence(L, model, seed, sample_size = 10, r = 1e-8, Ne = 100_000):
    
    demography=msprime.Demography()
    demography.add_population(initial_size=(Ne))
    
    ts = msprime.sim_ancestry(
        samples=sample_size,recombination_rate=r, sequence_length=L,
        demography=demography,
        ploidy=1,
        model=model,
        random_seed=seed, num_replicates=200)
    return list(ts)

def sample_selection_coefficient():

    selection_type = np.random.choice(["strong", "medium", "weak", "none"])
    selection_coefficient = {"strong":[1, 0.1], "medium":[0.1, 0.01], "weak":[0.01, 0.001], "none": None}
    selection_coefficient_range = selection_coefficient[selection_type]

    if selection_type != "none":
        s = np.round(np.random.uniform(selection_coefficient_range[0], selection_coefficient_range[1]), 3)
        return s, selection_type
    else:
        return 0, selection_type

    
def get_kingman_model(s, L, Ne = 100_000):
    if s != 0:
        model_kingman = [msprime.StandardCoalescent(duration=10), msprime.SweepGenicSelection(position=(L/2), start_frequency=(1/Ne),end_frequency=0.99,s=s,dt=(1/(40*Ne))), msprime.StandardCoalescent()]
    else:
        model_kingman = [msprime.StandardCoalescent(duration=10), msprime.StandardCoalescent()]
        
    return model_kingman


def get_beta_model(s, L, alpha, Ne = 100_000):
    if s != 0:
        model_beta_selection = [msprime.BetaCoalescent(alpha=alpha, duration=10), msprime.SweepGenicSelection(position=(L/2), start_frequency=(1/Ne),end_frequency=0.99,s=s,dt=(1/(40*Ne))), msprime.BetaCoalescent(alpha=alpha)]
    else:
        model_beta_selection = [msprime.BetaCoalescent(alpha=alpha, duration=10), msprime.BetaCoalescent(alpha=alpha)]
        
    return model_beta_selection


def get_mid_trees(ts):

    for i, tree in enumerate(ts.trees()):
        if tree.interval.left >= (ts.sequence_length/2):
            break

    first_tree = i-249
    last_tree = i + 250
    
    trees = []
    for j, tree in enumerate(ts.aslist()):
        if j >= first_tree and j <= last_tree:
            trees.append(tree)
            
    return trees

# %%
mkdir classification_dataset

# %%
np.random.seed(0x1337)
directory = "./classification_dataset/"


for nth_scenario in range(1000):

    if nth_scenario % 2 == 0:
    
    
        L = 100_000
        s, selection_type = sample_selection_coefficient()

        model_kingman = get_kingman_model(s, L)
        tree_sequences = simulate_tree_sequence(L, model_kingman, 1+nth_scenario*10)
        num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])

        while num_ts_above_1999 < 100:
            L = L*2
            #print(L)
            model_kingman = get_kingman_model(s, L)
            tree_sequences = simulate_tree_sequence(L, model_kingman, 1+nth_scenario*10)
            num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])


        c = 0
        for j, ts in enumerate(tree_sequences):

            if ts.num_trees >= 2000 and c < 100:
                y_dict = {"model": ("kingman", None), "sequence_length":L, "selection_coefficient":s, "selection_type":selection_type}
                torch.save((ts, y_dict),  open(str(directory) + "kingman_" + str(nth_scenario) + "_" + str(j) + ".pth", "wb"))
                c += 1
                
                
    else:
        
        L = 100_000
        s, selection_type = sample_selection_coefficient()
        alpha = np.round(np.random.uniform(1.01, 1.99), 2)

        model_beta = get_beta_model(s, L, alpha)
        tree_sequences = simulate_tree_sequence(L, model_beta, 1+nth_scenario*10)
        num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])

        while num_ts_above_1999 < 100:
            L = L*2
            #print(L, num_ts_above_1999)
            model_beta = get_beta_model(s, L, alpha)
            tree_sequences = simulate_tree_sequence(L, model_beta, 1+nth_scenario*10)
            num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])


        c = 0
        for j, ts in enumerate(tree_sequences):

            if ts.num_trees >= 2000 and c < 100:
                y_dict = {"model": ("beta", alpha), "sequence_length":L, "selection_coefficient":s, "selection_type":selection_type}
                torch.save((ts, y_dict),  open(str(directory) + "beta_" + str(nth_scenario) + "_" + str(j) + ".pth", "wb"))
                c += 1

    print(nth_scenario, y_dict)
# Out:
# 0 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.041, 'selection_type': 'medium'}
# 1 {'model': ('beta', 1.43), 'sequence_length': 204800000, 'selection_coefficient': 0.46, 'selection_type': 'strong'}
# 2 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.046, 'selection_type': 'medium'}
# 3 {'model': ('beta', 1.56), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 4 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 5 {'model': ('beta', 1.26), 'sequence_length': 6400000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 6 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 7 {'model': ('beta', 1.02), 'sequence_length': 204800000, 'selection_coefficient': 0.099, 'selection_type': 'medium'}
# 8 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.11, 'selection_type': 'strong'}
# 9 {'model': ('beta', 1.46), 'sequence_length': 102400000, 'selection_coefficient': 0.081, 'selection_type': 'medium'}
# 10 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 11 {'model': ('beta', 1.35), 'sequence_length': 409600000, 'selection_coefficient': 0.511, 'selection_type': 'strong'}
# 12 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 13 {'model': ('beta', 1.6), 'sequence_length': 6400000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 14 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 15 {'model': ('beta', 1.34), 'sequence_length': 102400000, 'selection_coefficient': 0.079, 'selection_type': 'medium'}
# 16 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.276, 'selection_type': 'strong'}
# 17 {'model': ('beta', 1.52), 'sequence_length': 102400000, 'selection_coefficient': 0.999, 'selection_type': 'strong'}
# 18 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.143, 'selection_type': 'strong'}
# 19 {'model': ('beta', 1.13), 'sequence_length': 819200000, 'selection_coefficient': 0.303, 'selection_type': 'strong'}
# 20 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.049, 'selection_type': 'medium'}
# 21 {'model': ('beta', 1.02), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 22 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 23 {'model': ('beta', 1.76), 'sequence_length': 25600000, 'selection_coefficient': 0.607, 'selection_type': 'strong'}
# 24 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 25 {'model': ('beta', 1.8), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 26 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.753, 'selection_type': 'strong'}
# 27 {'model': ('beta', 1.13), 'sequence_length': 1638400000, 'selection_coefficient': 0.846, 'selection_type': 'strong'}
# 28 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.021, 'selection_type': 'medium'}
# 29 {'model': ('beta', 1.06), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 30 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 31 {'model': ('beta', 1.24), 'sequence_length': 51200000, 'selection_coefficient': 0.02, 'selection_type': 'medium'}
# 32 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 33 {'model': ('beta', 1.7), 'sequence_length': 25600000, 'selection_coefficient': 0.159, 'selection_type': 'strong'}
# 34 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 35 {'model': ('beta', 1.82), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 36 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 37 {'model': ('beta', 1.68), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 38 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 39 {'model': ('beta', 1.12), 'sequence_length': 204800000, 'selection_coefficient': 0.053, 'selection_type': 'medium'}
# 40 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.288, 'selection_type': 'strong'}
# 41 {'model': ('beta', 1.66), 'sequence_length': 25600000, 'selection_coefficient': 0.052, 'selection_type': 'medium'}
# 42 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 43 {'model': ('beta', 1.84), 'sequence_length': 25600000, 'selection_coefficient': 0.793, 'selection_type': 'strong'}
# 44 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 45 {'model': ('beta', 1.65), 'sequence_length': 12800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 46 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 47 {'model': ('beta', 1.16), 'sequence_length': 25600000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 48 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.567, 'selection_type': 'strong'}
# 49 {'model': ('beta', 1.66), 'sequence_length': 12800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 50 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.298, 'selection_type': 'strong'}
# 51 {'model': ('beta', 1.34), 'sequence_length': 409600000, 'selection_coefficient': 0.408, 'selection_type': 'strong'}
# 52 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 53 {'model': ('beta', 1.53), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 54 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.074, 'selection_type': 'medium'}
# 55 {'model': ('beta', 1.38), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 56 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 57 {'model': ('beta', 1.13), 'sequence_length': 25600000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 58 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 59 {'model': ('beta', 1.77), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 60 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 61 {'model': ('beta', 1.89), 'sequence_length': 3200000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 62 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.505, 'selection_type': 'strong'}
# 63 {'model': ('beta', 1.34), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 64 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 65 {'model': ('beta', 1.13), 'sequence_length': 819200000, 'selection_coefficient': 0.166, 'selection_type': 'strong'}
# 66 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.451, 'selection_type': 'strong'}
# 67 {'model': ('beta', 1.79), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 68 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 69 {'model': ('beta', 1.43), 'sequence_length': 12800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 70 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.041, 'selection_type': 'medium'}
# 71 {'model': ('beta', 1.61), 'sequence_length': 51200000, 'selection_coefficient': 0.868, 'selection_type': 'strong'}
# 72 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.032, 'selection_type': 'medium'}
# 73 {'model': ('beta', 1.08), 'sequence_length': 819200000, 'selection_coefficient': 0.226, 'selection_type': 'strong'}
# 74 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 75 {'model': ('beta', 1.82), 'sequence_length': 25600000, 'selection_coefficient': 0.688, 'selection_type': 'strong'}
# 76 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 77 {'model': ('beta', 1.51), 'sequence_length': 12800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 78 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.095, 'selection_type': 'medium'}
# 79 {'model': ('beta', 1.74), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 80 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 81 {'model': ('beta', 1.62), 'sequence_length': 12800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 82 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 83 {'model': ('beta', 1.21), 'sequence_length': 102400000, 'selection_coefficient': 0.023, 'selection_type': 'medium'}
# 84 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.854, 'selection_type': 'strong'}
# 85 {'model': ('beta', 1.52), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 86 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.091, 'selection_type': 'medium'}
# 87 {'model': ('beta', 1.04), 'sequence_length': 6400000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 88 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.08, 'selection_type': 'medium'}
# 89 {'model': ('beta', 1.67), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 90 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.025, 'selection_type': 'medium'}
# 91 {'model': ('beta', 1.98), 'sequence_length': 25600000, 'selection_coefficient': 0.064, 'selection_type': 'medium'}
# 92 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.592, 'selection_type': 'strong'}
# 93 {'model': ('beta', 1.25), 'sequence_length': 51200000, 'selection_coefficient': 0.023, 'selection_type': 'medium'}
# 94 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 95 {'model': ('beta', 1.91), 'sequence_length': 12800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 96 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 97 {'model': ('beta', 1.27), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 98 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 99 {'model': ('beta', 1.38), 'sequence_length': 51200000, 'selection_coefficient': 0.033, 'selection_type': 'medium'}
# 100 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 101 {'model': ('beta', 1.97), 'sequence_length': 25600000, 'selection_coefficient': 0.742, 'selection_type': 'strong'}
# 102 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.146, 'selection_type': 'strong'}
# 103 {'model': ('beta', 1.33), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 104 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.017, 'selection_type': 'medium'}
# 105 {'model': ('beta', 1.88), 'sequence_length': 6400000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 106 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.087, 'selection_type': 'medium'}
# 107 {'model': ('beta', 1.64), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 108 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.848, 'selection_type': 'strong'}
# 109 {'model': ('beta', 1.52), 'sequence_length': 51200000, 'selection_coefficient': 0.033, 'selection_type': 'medium'}
# 110 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.062, 'selection_type': 'medium'}
# 111 {'model': ('beta', 1.46), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 112 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.032, 'selection_type': 'medium'}
# 113 {'model': ('beta', 1.09), 'sequence_length': 1638400000, 'selection_coefficient': 0.368, 'selection_type': 'strong'}
# 114 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.456, 'selection_type': 'strong'}
# 115 {'model': ('beta', 1.12), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 116 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 117 {'model': ('beta', 1.58), 'sequence_length': 102400000, 'selection_coefficient': 0.925, 'selection_type': 'strong'}
# 118 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.09, 'selection_type': 'medium'}
# 119 {'model': ('beta', 1.62), 'sequence_length': 51200000, 'selection_coefficient': 0.95, 'selection_type': 'strong'}
# 120 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.074, 'selection_type': 'medium'}
# 121 {'model': ('beta', 1.53), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 122 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 123 {'model': ('beta', 1.44), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 124 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.03, 'selection_type': 'medium'}
# 125 {'model': ('beta', 1.28), 'sequence_length': 102400000, 'selection_coefficient': 0.065, 'selection_type': 'medium'}
# 126 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 127 {'model': ('beta', 1.65), 'sequence_length': 51200000, 'selection_coefficient': 0.474, 'selection_type': 'strong'}
# 128 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.667, 'selection_type': 'strong'}
# 129 {'model': ('beta', 1.91), 'sequence_length': 6400000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 130 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 131 {'model': ('beta', 1.91), 'sequence_length': 12800000, 'selection_coefficient': 0.057, 'selection_type': 'medium'}
# 132 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.676, 'selection_type': 'strong'}
# 133 {'model': ('beta', 1.62), 'sequence_length': 25600000, 'selection_coefficient': 0.033, 'selection_type': 'medium'}
# 134 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.098, 'selection_type': 'medium'}
# 135 {'model': ('beta', 1.53), 'sequence_length': 51200000, 'selection_coefficient': 0.042, 'selection_type': 'medium'}
# 136 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.032, 'selection_type': 'medium'}
# 137 {'model': ('beta', 1.96), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 138 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 139 {'model': ('beta', 1.17), 'sequence_length': 204800000, 'selection_coefficient': 0.088, 'selection_type': 'medium'}
# 140 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 141 {'model': ('beta', 1.94), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 142 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 143 {'model': ('beta', 1.99), 'sequence_length': 51200000, 'selection_coefficient': 0.088, 'selection_type': 'medium'}
# 144 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 145 {'model': ('beta', 1.3), 'sequence_length': 102400000, 'selection_coefficient': 0.07, 'selection_type': 'medium'}
# 146 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 147 {'model': ('beta', 1.31), 'sequence_length': 25600000, 'selection_coefficient': 0.008, 'selection_type': 'weak'}
# 148 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.063, 'selection_type': 'medium'}
# 149 {'model': ('beta', 1.38), 'sequence_length': 102400000, 'selection_coefficient': 0.073, 'selection_type': 'medium'}
# 150 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.468, 'selection_type': 'strong'}
# 151 {'model': ('beta', 1.04), 'sequence_length': 12800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 152 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 153 {'model': ('beta', 1.78), 'sequence_length': 25600000, 'selection_coefficient': 0.93, 'selection_type': 'strong'}
# 154 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.097, 'selection_type': 'medium'}
# 155 {'model': ('beta', 1.76), 'sequence_length': 25600000, 'selection_coefficient': 0.052, 'selection_type': 'medium'}
# 156 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 157 {'model': ('beta', 1.37), 'sequence_length': 25600000, 'selection_coefficient': 0.008, 'selection_type': 'weak'}
# 158 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 159 {'model': ('beta', 1.5), 'sequence_length': 6400000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 160 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.066, 'selection_type': 'medium'}
# 161 {'model': ('beta', 1.54), 'sequence_length': 102400000, 'selection_coefficient': 0.782, 'selection_type': 'strong'}
# 162 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.015, 'selection_type': 'medium'}
# 163 {'model': ('beta', 1.1), 'sequence_length': 25600000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 164 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.04, 'selection_type': 'medium'}
# 165 {'model': ('beta', 1.43), 'sequence_length': 204800000, 'selection_coefficient': 0.67, 'selection_type': 'strong'}
# 166 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.748, 'selection_type': 'strong'}
# 167 {'model': ('beta', 1.67), 'sequence_length': 6400000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 168 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.008, 'selection_type': 'weak'}
# 169 {'model': ('beta', 1.64), 'sequence_length': 6400000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 170 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 171 {'model': ('beta', 1.91), 'sequence_length': 6400000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 172 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.228, 'selection_type': 'strong'}
# 173 {'model': ('beta', 1.1), 'sequence_length': 1638400000, 'selection_coefficient': 0.378, 'selection_type': 'strong'}
# 174 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.245, 'selection_type': 'strong'}
# 175 {'model': ('beta', 1.61), 'sequence_length': 6400000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 176 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.546, 'selection_type': 'strong'}
# 177 {'model': ('beta', 1.67), 'sequence_length': 25600000, 'selection_coefficient': 0.036, 'selection_type': 'medium'}
# 178 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.078, 'selection_type': 'medium'}
# 179 {'model': ('beta', 1.05), 'sequence_length': 1638400000, 'selection_coefficient': 0.711, 'selection_type': 'strong'}
# 180 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.011, 'selection_type': 'medium'}
# 181 {'model': ('beta', 1.51), 'sequence_length': 51200000, 'selection_coefficient': 0.026, 'selection_type': 'medium'}
# 182 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.01, 'selection_type': 'medium'}
# 183 {'model': ('beta', 1.69), 'sequence_length': 6400000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 184 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 185 {'model': ('beta', 1.71), 'sequence_length': 6400000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 186 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 187 {'model': ('beta', 1.82), 'sequence_length': 3200000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 188 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 189 {'model': ('beta', 1.69), 'sequence_length': 51200000, 'selection_coefficient': 0.819, 'selection_type': 'strong'}
# 190 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 191 {'model': ('beta', 1.61), 'sequence_length': 25600000, 'selection_coefficient': 0.016, 'selection_type': 'medium'}
# 192 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 193 {'model': ('beta', 1.3), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 194 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.01, 'selection_type': 'weak'}
# 195 {'model': ('beta', 1.98), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 196 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 197 {'model': ('beta', 1.37), 'sequence_length': 102400000, 'selection_coefficient': 0.079, 'selection_type': 'medium'}
# 198 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.751, 'selection_type': 'strong'}
# 199 {'model': ('beta', 1.85), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 200 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.072, 'selection_type': 'medium'}
# 201 {'model': ('beta', 1.47), 'sequence_length': 102400000, 'selection_coefficient': 0.351, 'selection_type': 'strong'}
# 202 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 203 {'model': ('beta', 1.13), 'sequence_length': 12800000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 204 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}
# 205 {'model': ('beta', 1.65), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 206 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.076, 'selection_type': 'medium'}
# 207 {'model': ('beta', 1.65), 'sequence_length': 51200000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 208 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 209 {'model': ('beta', 1.95), 'sequence_length': 12800000, 'selection_coefficient': 0.058, 'selection_type': 'medium'}
# 210 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.757, 'selection_type': 'strong'}
# 211 {'model': ('beta', 1.62), 'sequence_length': 51200000, 'selection_coefficient': 0.755, 'selection_type': 'strong'}
# 212 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 213 {'model': ('beta', 1.16), 'sequence_length': 25600000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 214 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 215 {'model': ('beta', 1.05), 'sequence_length': 409600000, 'selection_coefficient': 0.095, 'selection_type': 'medium'}
# 216 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 217 {'model': ('beta', 1.77), 'sequence_length': 12800000, 'selection_coefficient': 0.01, 'selection_type': 'weak'}
# 218 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 219 {'model': ('beta', 1.11), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 220 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 221 {'model': ('beta', 1.04), 'sequence_length': 1638400000, 'selection_coefficient': 0.524, 'selection_type': 'strong'}
# 222 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.193, 'selection_type': 'strong'}
# 223 {'model': ('beta', 1.31), 'sequence_length': 409600000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 224 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 225 {'model': ('beta', 1.73), 'sequence_length': 25600000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 226 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.08, 'selection_type': 'medium'}
# 227 {'model': ('beta', 1.81), 'sequence_length': 25600000, 'selection_coefficient': 0.484, 'selection_type': 'strong'}
# 228 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.548, 'selection_type': 'strong'}
# 229 {'model': ('beta', 1.43), 'sequence_length': 102400000, 'selection_coefficient': 0.098, 'selection_type': 'medium'}
# 230 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.076, 'selection_type': 'medium'}
# 231 {'model': ('beta', 1.39), 'sequence_length': 204800000, 'selection_coefficient': 0.831, 'selection_type': 'strong'}
# 232 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.078, 'selection_type': 'medium'}
# 233 {'model': ('beta', 1.93), 'sequence_length': 12800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 234 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.23, 'selection_type': 'strong'}
# 235 {'model': ('beta', 1.6), 'sequence_length': 25600000, 'selection_coefficient': 0.036, 'selection_type': 'medium'}
# 236 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 237 {'model': ('beta', 1.61), 'sequence_length': 51200000, 'selection_coefficient': 0.095, 'selection_type': 'medium'}
# 238 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 239 {'model': ('beta', 1.53), 'sequence_length': 102400000, 'selection_coefficient': 0.351, 'selection_type': 'strong'}
# 240 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 241 {'model': ('beta', 1.45), 'sequence_length': 25600000, 'selection_coefficient': 0.014, 'selection_type': 'medium'}
# 242 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 243 {'model': ('beta', 1.73), 'sequence_length': 25600000, 'selection_coefficient': 0.097, 'selection_type': 'medium'}
# 244 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.65, 'selection_type': 'strong'}
# 245 {'model': ('beta', 1.56), 'sequence_length': 51200000, 'selection_coefficient': 0.028, 'selection_type': 'medium'}
# 246 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.621, 'selection_type': 'strong'}
# 247 {'model': ('beta', 1.79), 'sequence_length': 12800000, 'selection_coefficient': 0.031, 'selection_type': 'medium'}
# 248 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.699, 'selection_type': 'strong'}
# 249 {'model': ('beta', 1.21), 'sequence_length': 819200000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 250 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.394, 'selection_type': 'strong'}
# 251 {'model': ('beta', 1.36), 'sequence_length': 409600000, 'selection_coefficient': 0.898, 'selection_type': 'strong'}
# 252 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.04, 'selection_type': 'medium'}
# 253 {'model': ('beta', 1.66), 'sequence_length': 6400000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 254 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 255 {'model': ('beta', 1.96), 'sequence_length': 25600000, 'selection_coefficient': 0.049, 'selection_type': 'medium'}
# 256 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.684, 'selection_type': 'strong'}
# 257 {'model': ('beta', 1.93), 'sequence_length': 6400000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 258 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.006, 'selection_type': 'weak'}
# 259 {'model': ('beta', 1.49), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 260 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 261 {'model': ('beta', 1.46), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 262 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 263 {'model': ('beta', 1.48), 'sequence_length': 102400000, 'selection_coefficient': 0.273, 'selection_type': 'strong'}
# 264 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.097, 'selection_type': 'medium'}
# 265 {'model': ('beta', 1.49), 'sequence_length': 102400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 266 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 267 {'model': ('beta', 1.47), 'sequence_length': 6400000, 'selection_coefficient': 0.003, 'selection_type': 'weak'}
# 268 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.024, 'selection_type': 'medium'}
# 269 {'model': ('beta', 1.16), 'sequence_length': 1638400000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 270 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.554, 'selection_type': 'strong'}
# 271 {'model': ('beta', 1.47), 'sequence_length': 3200000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 272 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.008, 'selection_type': 'weak'}
# 273 {'model': ('beta', 1.37), 'sequence_length': 409600000, 'selection_coefficient': 0.78, 'selection_type': 'strong'}
# 274 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.582, 'selection_type': 'strong'}
# 275 {'model': ('beta', 1.36), 'sequence_length': 51200000, 'selection_coefficient': 0.016, 'selection_type': 'medium'}
# 276 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 277 {'model': ('beta', 1.61), 'sequence_length': 12800000, 'selection_coefficient': 0.008, 'selection_type': 'weak'}
# 278 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.036, 'selection_type': 'medium'}
# 279 {'model': ('beta', 1.61), 'sequence_length': 51200000, 'selection_coefficient': 0.801, 'selection_type': 'strong'}
# 280 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 281 {'model': ('beta', 1.86), 'sequence_length': 6400000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 282 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.082, 'selection_type': 'medium'}
# 283 {'model': ('beta', 1.4), 'sequence_length': 25600000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 284 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.089, 'selection_type': 'medium'}
# 285 {'model': ('beta', 1.31), 'sequence_length': 12800000, 'selection_coefficient': 0.005, 'selection_type': 'weak'}
# 286 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.688, 'selection_type': 'strong'}
# 287 {'model': ('beta', 1.4), 'sequence_length': 204800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 288 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.061, 'selection_type': 'medium'}
# 289 {'model': ('beta', 1.96), 'sequence_length': 25600000, 'selection_coefficient': 0.172, 'selection_type': 'strong'}
# 290 {'model': ('kingman', None), 'sequence_length': 3200000, 'selection_coefficient': 0.399, 'selection_type': 'strong'}
# 291 {'model': ('beta', 1.65), 'sequence_length': 6400000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 292 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.007, 'selection_type': 'weak'}
# 293 {'model': ('beta', 1.51), 'sequence_length': 3200000, 'selection_coefficient': 0.001, 'selection_type': 'weak'}
# 294 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.049, 'selection_type': 'medium'}
# 295 {'model': ('beta', 1.95), 'sequence_length': 12800000, 'selection_coefficient': 0.009, 'selection_type': 'weak'}
# 296 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0, 'selection_type': 'none'}
# 297 {'model': ('beta', 1.42), 'sequence_length': 102400000, 'selection_coefficient': 0.069, 'selection_type': 'medium'}
# 298 {'model': ('kingman', None), 'sequence_length': 800000, 'selection_coefficient': 0.002, 'selection_type': 'weak'}
# 299 {'model': ('beta', 1.15), 'sequence_length': 1638400000, 'selection_coefficient': 0.799, 'selection_type': 'strong'}
# 300 {'model': ('kingman', None), 'sequence_length': 1600000, 'selection_coefficient': 0.053, 'selection_type': 'medium'}
# 301 {'model': ('beta', 1.66), 'sequence_length': 6400000, 'selection_coefficient': 0.004, 'selection_type': 'weak'}

# %%
ls validation_classification_dataset

# %%
mkdir validation_classification_dataset

# %%
np.random.seed(0x999999)
directory = "./validation_classification_dataset/"


for nth_scenario in range(10000):

    if nth_scenario % 2 == 0:
    
    
        L = 100_000
        s, selection_type = sample_selection_coefficient()

        model_kingman = get_kingman_model(s, L)
        tree_sequences = simulate_tree_sequence(L, model_kingman, 1+nth_scenario*10)
        num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])

        while num_ts_above_1999 < 1:
            L = L*2
            #print(L)
            model_kingman = get_kingman_model(s, L)
            tree_sequences = simulate_tree_sequence(L, model_kingman, 1+nth_scenario*10)
            num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])


        c = 0
        for j, ts in enumerate(tree_sequences):

            if ts.num_trees >= 2000 and c < 1:
                y_dict = {"model": ("kingman", None), "sequence_length":L, "selection_coefficient":s, "selection_type":selection_type}
                torch.save((ts, y_dict),  open(str(directory) + "kingman_" + str(nth_scenario) + "_" + str(j) + ".pth", "wb"))
                c += 1
                
                
    else:
        
        L = 100_000
        s, selection_type = sample_selection_coefficient()
        alpha = np.round(np.random.uniform(1.01, 1.99), 2)

        model_beta = get_beta_model(s, L, alpha)
        tree_sequences = simulate_tree_sequence(L, model_beta, 1+nth_scenario*10)
        num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])

        while num_ts_above_1999 < 1:
            L = L*2
            #print(L, num_ts_above_1999)
            model_beta = get_beta_model(s, L, alpha)
            tree_sequences = simulate_tree_sequence(L, model_beta, 1+nth_scenario*10)
            num_ts_above_1999 = np.sum([1 if ts.num_trees >= 2000 else 0 for ts in tree_sequences])


        c = 0
        for j, ts in enumerate(tree_sequences):

            if ts.num_trees >= 2000 and c < 1:
                y_dict = {"model": ("beta", alpha), "sequence_length":L, "selection_coefficient":s, "selection_type":selection_type}
                torch.save((ts, y_dict),  open(str(directory) + "beta_" + str(nth_scenario) + "_" + str(j) + ".pth", "wb"))
                c += 1

    print(nth_scenario, y_dict)
